# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import pandas as pd
from statannot import add_stat_annotation
import itertools

# %%
N = 16
scenarios = ["random 30%","mixa","mixb","mixc","mixd"]
models = ["baseline", "ae", "ae_clf", "vae"]

# %%
# gbm_neftel 70 30 split
lo_gbm = pd.DataFrame()
lo_gbm["baseline"] = np.repeat(0.1627389696271556, N)
lo_gbm["ae"] = [0.1641072100316012, 0.1523569101161811, 0.13175625695826412, 0.15546217339708743, 0.15307598488861315, 0.13653502133870155, 0.13565481761760692, 0.15219794439286854, 0.15248771285507684, 0.1416435453074403, 0.1446793548389273, 0.16063865237602495, 0.16161912289057692, 0.14209512274816005, 0.149290320985953, 0.14292239155010505]
lo_gbm["ae_clf"] = [0.10687987576993215, 0.11052747128852226, 0.10429141012777243, 0.10997036621625893, 0.10625323703498517, 0.10804392202938212, 0.11067691333312593, 0.10293358718965596, 0.1081988571681895, 0.10628916983288639, 0.10506994451122106, 0.10777925225342626, 0.10853130705629038, 0.10794147231257722, 0.10620478724606801, 0.1083050373255823]
lo_gbm["vae"] = [0.1210743624621806, 0.12425227746860956, 0.12108298394353947, 0.12686262408812646, 0.12020089257704461, 0.11258049082413861, 0.11917479791427389, 0.11498562689491047, 0.11421057361981456, 0.11904838123887262, 0.12197473800581854, 0.11970501418182705, 0.12148764081102571, 0.12309814308158944, 0.12750346292995493, 0.11848523940963647]

# %%
ax = sns.boxplot(lo_gbm)
#plt.title("GBM 70%/30% split on test set")
plt.ylabel("RMSE")
add_stat_annotation(ax, data=lo_gbm, test="Mann-Whitney",box_pairs=[("ae_clf", "vae"),("baseline","ae")])
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# ae_clf v.s. vae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=3.090e-06 U_stat=0.000e+00
# baseline v.s. ae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.414e-05 U_stat=2.400e+02
# (<AxesSubplot: ylabel='RMSE'>,
# ...
#   <statannot.StatResult.StatResult at 0x14a9a34c0>])

# %%
# leave out mixd
lo_mixd = pd.DataFrame()
lo_mixd["baseline"] = np.repeat(0.03298746480286895, N)
lo_mixd["ae"] = [0.04239036845423635, 0.03190038010232961, 0.028254696935313003, 0.040688880827632494, 0.03955197089955974, 0.027681427069160408, 0.029238911504889456, 0.0285788639230204, 0.028818832119107782, 0.027233757677526314, 0.037370506484213716, 0.09457273390447908, 0.030582160336059094, 0.06724060276227044, 0.12487178477925148, 0.03165996124269722]
lo_mixd["ae_clf"] = [0.00417876887473179, 0.003996109036985513, 0.0038565593953041777, 0.004443355117538508, 0.004300341768462045, 0.004102392468697347, 0.003959031044356309, 0.0036241134116845124, 0.0038423679060554483, 0.004033686330706939, 0.005097683845242013, 0.004002968242225765, 0.004550190909869827, 0.00392023022376935, 0.005269923283795778, 0.00394528104996444]
lo_mixd["vae"] = [0.008791840338044496, 0.01091941380646175, 0.018590825218755866, 0.011599818200556476, 0.011543565881001333, 0.007316213695567201, 0.011756327186135172, 0.011568342101586235, 0.01490561639376101, 0.016747047763829855, 0.013880792986383238, 0.011011529344414156, 0.019402487088476278, 0.009777072609384273, 0.011294035535206345, 0.016195191998927536]

# %%
ax = sns.boxplot(lo_mixd)
plt.title("train on mix{a,b,d} & test on mixd")
plt.ylabel("RMSE")
add_stat_annotation(ax, data=lo_mixd, test="Mann-Whitney",box_pairs=[("ae_clf","vae")])
#plt.ylim([0,0.1])
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# ae_clf v.s. vae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.545e-06 U_stat=0.000e+00
# (<AxesSubplot: title={'center': 'train on mix{a,b,d} & test on mixd'}, ylabel='RMSE'>,
#  [<statannot.StatResult.StatResult at 0x14129a430>])

# %%
# leave out mixc
lo_mixc = pd.DataFrame()
lo_mixc["baseline"] = np.repeat(0.03052072681809904, N)
lo_mixc["ae"] = [0.05869920792306878, 0.057206945660423295, 0.054995164786520716, 0.05815351828822797, 0.06043410482170362, 0.06330969290298913, 0.05697097373425456, 0.054767385145844664, 0.05904505892437893, 0.05604649638519174, 0.062076392771805114, 0.05276954060937075, 0.05473951269628676, 0.057660900760605316, 0.05969024634660189, 0.05924572358279891]
lo_mixc["ae_clf"] = [0.0041395198481000905, 0.004360148013270259, 0.00836142370986347, 0.005261065806586069, 0.003789417262942967, 0.004589474054861503, 0.01260619908738042, 0.0059517010365615144, 0.006927548447529461, 0.005539035621507425, 0.005619773118751551, 0.007704418208806078, 0.005017980172276722, 0.00725843907803425, 0.004598533524307567, 0.007470574223163263]
lo_mixc["vae"] = [0.007452937191462813, 0.008268981860091383, 0.008080355551169581, 0.008147752852477671, 0.008236264607715895, 0.008371593119110557, 0.01108002297673462, 0.007831054875681004, 0.012447923009455046, 0.009368146934953166, 0.006772502726007059, 0.008421880832965826, 0.012882070215821502, 0.009227516086895338, 0.02027744663590904, 0.01085958835763338]

# %%
ax = sns.boxplot(lo_mixc)
plt.title("train on mix{a,b,d} & test on mixc")
plt.ylabel("RMSE")
add_stat_annotation(ax, data=lo_mixc, test="Mann-Whitney",box_pairs=[("ae_clf","vae")])

#plt.ylim([0,0.1])
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# ae_clf v.s. vae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.520e-04 U_stat=2.700e+01
# (<AxesSubplot: title={'center': 'train on mix{a,b,d} & test on mixc'}, ylabel='RMSE'>,
#  [<statannot.StatResult.StatResult at 0x1414083a0>])

# %%
# leave out mixb
lo_mixb = pd.DataFrame()
lo_mixb["baseline"] = np.repeat(0.06977076257209835, N)
lo_mixb["ae"] = [0.033680788517599584, 0.05879805618892912, 0.026456204192911555, 0.025104600382839532, 0.041974792776618405, 0.0348799504655241, 0.03529039923737558, 0.0313840640112513, 0.044430788321235336, 0.03443586664016375, 0.031127468868391513, 0.026474114374420838, 0.06907087745208092, 0.030067333198577757, 0.016869542431670766, 0.030408189340409404]
lo_mixb["ae_clf"] = [0.0048761115879756315, 0.004766827507668678, 0.0035929383468719903, 0.003560603937965215, 0.003347564223424563, 0.00463700912605473, 0.003923429266351201, 0.0039393179701314, 0.003741968995485551, 0.003470327181905652, 0.0035409583892191455, 0.004036234768076431, 0.0032938668887604865, 0.00368386107844286, 0.004321578259583901, 0.0043574574906009595]
lo_mixb["vae"] = [0.016137218998364494, 0.02363375460955802, 0.024332831197549556, 0.023706081723200517, 0.026983998483910084, 0.02084204499420495, 0.024132529053443708, 0.02503322728297129, 0.025996990457695233, 0.020317838629933412, 0.024949232357694535, 0.019304454615115853, 0.021083253804002333, 0.019260466245793712, 0.026618103788373017, 0.02708241131735702]

# %%
ax = sns.boxplot(lo_mixb)
plt.title("train on mix{a,c,d} & test on mixb")
plt.ylabel("RMSE")
add_stat_annotation(ax, data=lo_mixb, test="Mann-Whitney",box_pairs=[("ae","vae"),("baseline","ae")])
#plt.ylim([0,0.1])
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# baseline v.s. ae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.612e-07 U_stat=2.560e+02
# ae v.s. vae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.239e-04 U_stat=2.310e+02
# (<AxesSubplot: title={'center': 'train on mix{a,c,d} & test on mixb'}, ylabel='RMSE'>,
# ...
#   <statannot.StatResult.StatResult at 0x14157fb80>])

# %%
# leave out mixa
lo_mixa = pd.DataFrame()
lo_mixa["baseline"] = np.repeat(0.06077355420937027, N)
lo_mixa["ae"] = [0.05906663787847787, 0.042579050581610635, 0.05527471936613794, 0.04777351460309045, 0.050382498843631926, 0.061416428646751016, 0.05274813942322226, 0.06473060291429829, 0.04468252023625627, 0.05874337124396686, 0.04748710952367772, 0.06190428237334878, 0.05480609875880219, 0.053178731616541845, 0.04453272301500626, 0.05825791477120836]
lo_mixa["ae_clf"] = [0.003828622264747679, 0.004733529131389026, 0.0037311437892967978, 0.004972312045514019, 0.003441567987328122, 0.004697247548566996, 0.004254351044339689, 0.00563167362691973, 0.004559211686576425, 0.004302445472600769, 0.0031979814555400097, 0.0037964695956816392, 0.0036477044054456873, 0.0036445591550517873, 0.0031284553070300833, 0.0036500821678654054]
lo_mixa["vae"] = [0.01603227765278236, 0.016138260967046823, 0.016196287638618342, 0.017962296247076175, 0.014616740789463779, 0.011794197333555384, 0.015076112397700018, 0.01816422606273749, 0.016677081770517677, 0.020844792536773512, 0.017128609814887757, 0.018317671171831244, 0.014623818614773422, 0.014004699261244067, 0.02330371774961117, 0.01569417789753053]

# %%
ax = sns.boxplot(lo_mixa)
plt.title("train on mix{b,c,d} & test on mixa")
plt.ylabel("RMSE")
add_stat_annotation(ax, data=lo_mixa, test="Mann-Whitney",box_pairs=[("ae","baseline")])
#plt.ylim([0,0.1])
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# baseline v.s. ae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.363e-03 U_stat=2.080e+02
# (<AxesSubplot: title={'center': 'train on mix{b,c,d} & test on mixa'}, ylabel='RMSE'>,
#  [<statannot.StatResult.StatResult at 0x14170a130>])

# %%
# 30 70 split
lo_arb = pd.DataFrame()
lo_arb["baseline"] = np.repeat(0.05179220528762823, N)
lo_arb["ae"] = [0.04830250548682451, 0.03733902389035984, 0.038846036195146594, 0.06484816073238887, 0.03696991368917225, 0.03709795716926695, 0.04068697338544007, 0.04353500597781323, 0.040363095727604555, 0.05461641079880037, 0.03678264055122587, 0.04238655448887539, 0.03528435013289567, 0.039145398430365214, 0.03799279849427749, 0.039908555813912575]
lo_arb["ae_clf"] = [0.004232165891048388, 0.004340261479200732, 0.0044254703210884145, 0.0047419547685038695, 0.0037636365224817682, 0.0045525692084142895, 0.0047698231097690075, 0.004016777818433932, 0.0047003152320897, 0.00369454737636697, 0.004171018430102446, 0.003990899178018842, 0.004663125552540134, 0.003998997751860915, 0.005309512117601597, 0.004730792539090702]
lo_arb["vae"] = [0.010796728956661977, 0.01285838774799937, 0.014767969327582774, 0.013183629425575568, 0.014975288011354462, 0.014106132185156951, 0.015730805019693952, 0.01825979832258511, 0.015660450822921404, 0.016640913783944805, 0.01412956184424326, 0.012513267359360066, 0.014087691647795194, 0.012060524256447947, 0.016472085897670286, 0.015549029253557745]

# %%
ax = sns.boxplot(lo_arb)
plt.title("train on 70% & test on 30%")
plt.ylabel("RMSE")
add_stat_annotation(ax, data=lo_arb, test="Mann-Whitney",box_pairs=[("ae","baseline")])
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# baseline v.s. ae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.196e-04 U_stat=2.240e+02
# (<AxesSubplot: title={'center': 'train on 70% & test on 30%'}, ylabel='RMSE'>,
#  [<statannot.StatResult.StatResult at 0x1417c0160>])

# %%
types = list(itertools.chain(*([model]*N for model in models)))*len(scenarios)
scenario = list(itertools.chain(*([scenario]*N*len(models) for scenario in scenarios)))
rmse = np.concatenate((lo_arb.T.to_numpy().flatten(),lo_mixa.T.to_numpy().flatten(),lo_mixb.T.to_numpy().flatten(),lo_mixc.T.to_numpy().flatten(),lo_mixd.T.to_numpy().flatten()))

# type | rmse | scenario
df = pd.DataFrame.from_dict(data={"model": types, "test set": scenario, "RMSE": rmse})

plt.figure(figsize=(20,10))
ax = sns.boxplot(data=df, hue="model", x="test set", y="RMSE", hue_order=models, linewidth=2)
ax.set_title("Comparison of models on different test sets")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
add_stat_annotation(ax, data=df, test="Mann-Whitney",
                    hue="model", x="test set", y="RMSE",
                    hue_order=models, box_pairs=[
    (("random 30%","ae"), ("random 30%","ae_clf")),
    (("random 30%","ae"), ("random 30%","vae")),
    (("random 30%","ae_clf"), ("random 30%","vae")),
    (("random 30%","baseline"), ("random 30%","ae")),
    (("random 30%","baseline"), ("random 30%","ae_clf")),
    (("random 30%","baseline"), ("random 30%","vae")),
                        
    (("mixa","ae"), ("mixa","ae_clf")),
    (("mixa","ae"), ("mixa","vae")),
    (("mixa","ae_clf"), ("mixa","vae")),
    (("mixa","baseline"), ("mixa","ae")),
    (("mixa","baseline"), ("mixa","ae_clf")),
    (("mixa","baseline"), ("mixa","vae")),

    (("mixb","ae"), ("mixb","ae_clf")),
    (("mixb","ae"), ("mixb","vae")),
    (("mixb","ae_clf"), ("mixb","vae")),
    (("mixb","baseline"), ("mixb","ae")),
    (("mixb","baseline"), ("mixb","ae_clf")),
    (("mixb","baseline"), ("mixb","vae")),                        
  
    (("mixc","ae"), ("mixc","ae_clf")),
    (("mixc","ae"), ("mixc","vae")),
    (("mixc","ae_clf"), ("mixc","vae")),
    (("mixc","baseline"), ("mixc","ae")),
    (("mixc","baseline"), ("mixc","ae_clf")),
    (("mixc","baseline"), ("mixc","vae")),
                        
    (("mixd","ae"), ("mixd","ae_clf")),
    (("mixd","ae"), ("mixd","vae")),
    (("mixd","ae_clf"), ("mixd","vae")),
    (("mixd","baseline"), ("mixd","ae_clf")),
    (("mixd","baseline"), ("mixd","vae"))])
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# mixb_ae_clf v.s. mixb_vae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.480e-05 U_stat=0.000e+00
# mixc_ae_clf v.s. mixc_vae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.409e-03 U_stat=2.700e+01
# mixc_baseline v.s. mixc_ae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=8.137e-06 U_stat=0.000e+00
# mixd_ae v.s. mixd_ae_clf: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.480e-05 U_stat=2.560e+02
# mixa_ae_clf v.s. mixa_vae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.480e-05 U_stat=0.000e+00
# mixb_baseline v.s. mixb_ae: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=8.137e-06 U_stat=2.560e+02
# ...
